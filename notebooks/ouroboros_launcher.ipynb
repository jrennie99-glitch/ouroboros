# %% [markdown]
# # 🐍 Ouroboros — Super Supreme God Mode Launcher

# %%
# !pip install -q python-telegram-bot openai httpx pydantic
# !git clone https://github.com/AR-DYNAMICS/ouroboros-new.git /content/ouroboros_repo
# %cd /content/ouroboros_repo
# !git checkout ouroboros

# %%
import os

# ===== PASTE YOUR TOKENS HERE =====
os.environ["TELEGRAM_BOT_TOKEN"] = ""  # From @BotFather
os.environ["OPENROUTER_API_KEY"] = ""  # From openrouter.ai
os.environ["GITHUB_TOKEN"] = ""  # GitHub PAT with repo scope

# GitHub repo identity (required by launcher)
os.environ["GITHUB_USER"] = "AR-DYNAMICS"
os.environ["GITHUB_REPO"] = "ouroboros-new"

# Model config - free models
os.environ["OUROBOROS_MODEL"] = "meta-llama/llama-3.3-70b-instruct:free"
os.environ["OUROBOROS_MODEL_CODE"] = "meta-llama/llama-3.3-70b-instruct:free"
os.environ["OUROBOROS_MODEL_LIGHT"] = "meta-llama/llama-3.3-70b-instruct:free"

# Budget
os.environ["TOTAL_BUDGET"] = "0"
os.environ["OUROBOROS_MAX_ROUNDS"] = "15"

# %%
# %cd /content/ouroboros_repo
# !python colab_launcher.py

# %% [markdown]
# # 🐍 Ouroboros — Super Supreme God Mode Launcher

# %%
# !pip install -q python-telegram-bot openai httpx pydantic
# %cd /content
# !rm -rf ouroboros_repo
# !git clone -b ouroboros https://github.com/jrennie99-glitch/ouroboros.git ouroboros_repo
# %cd ouroboros_repo

# %%
import os

# ===== PASTE YOUR TOKENS HERE =====
os.environ["TELEGRAM_BOT_TOKEN"] = ""  # From @BotFather
os.environ["OPENROUTER_API_KEY"] = ""  # From openrouter.ai
os.environ["GITHUB_TOKEN"] = ""  # Optional - leave empty if not needed

# GitHub repo identity (required by launcher)
os.environ["GITHUB_USER"] = "jrennie99-glitch"
os.environ["GITHUB_REPO"] = "ouroboros"

# Model config - fast and cheap
os.environ["OUROBOROS_MODEL"] = "google/gemini-2.0-flash-lite-001"
os.environ["OUROBOROS_MODEL_CODE"] = "google/gemini-2.0-flash-lite-001"
os.environ["OUROBOROS_MODEL_LIGHT"] = "google/gemini-2.0-flash-lite-001"

# Budget
os.environ["TOTAL_BUDGET"] = "0"
os.environ["OUROBOROS_MAX_ROUNDS"] = "15"

# %%
import os
os.environ["OUROBOROS_SKIP_DRIVE"] = "1"

# %cd /content/ouroboros_repo
# !python local_launcher.py
